# %%
# !pip linstall -r requirements.txt
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            0.14.1
# addict                             2.4.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              3.6.1
# apache-beam                        2.37.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# avro-python3                       1.10.2
# ...

# %%
import cv2 
import torch
import time
# %matplotlib inline
import matplotlib.pyplot as plt
# calculate time in millisec
def current_milli_time():
    return round(time.time() * 1000)

# %%
# read model
model =  torch.hub.load(r'yolov5', 'custom', path = r'runs\train\yolov5m\weights\best.onnx', force_reload=True,source='local')
# Out:
# YOLOv5  2022-9-22 Python-3.8.12 torch-1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Loading runs\train\yolov5m\weights\best.onnx for ONNX Runtime inference...
# Adding AutoShape...

# %%
# change config in model
model.cpu()
model.conf = 0.1
model.iou = 0.4

# %%
# read image
image = cv2.imread(r'C:\Users\user\Documents\yolov5\Dataset\train\G0010117.jpg')
plt.figure(figsize=(25,25))
plt.imshow(image)

# %%
# inferencing
time1 = current_milli_time()
results = model(image) 
time2 = current_milli_time()
print('time(ms) :', time2 - time1)
# Out:
# time(ms) : 29

# %%
df_results = results.pandas().xyxy[0]
print(df_results)
for index,row in df_results.iterrows():
    print(row['name'])
    image_cropped = image[int(row['ymin']):int(row['ymax']),int(row['xmin']):int(row['xmax'])]
    rat = image_cropped.shape[0]/image_cropped.shape[1]
    
    start = (int(row['xmin']), int(row['ymin']))
    end = (int(row['xmax']), int(row['ymax']))
    
    image2 = cv2.rectangle(image,start ,end,(0,255,0),1)
plt.figure(figsize=(25,25))
plt.imshow(image2)
# Out:
#          xmin        ymin        xmax        ymax  confidence  class     name
# 0  449.418243  249.171814  465.047607  253.715958    0.530851      0  pothole
# 1  383.640930  283.861145  407.949219  290.248108    0.141600      0  pothole
# 2  411.169617  251.201324  433.039337  256.610992    0.132376      0  pothole
# pothole
# pothole
# pothole
